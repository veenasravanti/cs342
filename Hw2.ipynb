# %% [markdown]
# <a href="https://colab.research.google.com/github/veenasravanti/cs342/blob/homework1/Hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.environ['USER'] = 'veenasravanti'
os.environ['PASS'] = '1979Suresh'
os.environ['REPO'] = 'cs342'

# !git clone https://$USER:$PASS@github.com/$USER/$REPO.git
# Out:
# Cloning into 'cs342'...
# remote: Enumerating objects: 30083, done.
# remote: Counting objects: 100% (30083/30083), done.
# remote: Compressing objects: 100% (28459/28459), done.
# remote: Total 30083 (delta 1637), reused 30026 (delta 1617), pack-reused 0
# Receiving objects: 100% (30083/30083), 41.40 MiB | 23.62 MiB/s, done.
# Resolving deltas: 100% (1637/1637), done.
# Checking out files: 100% (30042/30042), done.

# %%
cd /content/cs342/homework2/
# Out:
# /content/cs342/homework2

# %%
# !wget https://www.cs.utexas.edu/~philkr/supertux_classification_trainval.zip
# Out:
# --2021-06-20 00:49:28--  https://www.cs.utexas.edu/~philkr/supertux_classification_trainval.zip
# Resolving www.cs.utexas.edu (www.cs.utexas.edu)... 128.83.120.48
# Connecting to www.cs.utexas.edu (www.cs.utexas.edu)|128.83.120.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48119548 (46M) [application/zip]
# Saving to: ‘supertux_classification_trainval.zip’
#
# supertux_classifica 100%[===================>]  45.89M  44.4MB/s    in 1.0s
#
# 2021-06-20 00:49:29 (44.4 MB/s) - ‘supertux_classification_trainval.zip’ saved [48119548/48119548]

# %%
# !wget https://www.cs.utexas.edu/~philkr/supertux_segmentation_trainval.zip
# !unzip -q supertux_classification_trainval.zip
# !unzip -q supertux_segmentation_trainval.zip
# Out:
# --2021-06-20 00:49:33--  https://www.cs.utexas.edu/~philkr/supertux_segmentation_trainval.zip
# Resolving www.cs.utexas.edu (www.cs.utexas.edu)... 128.83.120.48
# Connecting to www.cs.utexas.edu (www.cs.utexas.edu)|128.83.120.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57184517 (55M) [application/zip]
# Saving to: ‘supertux_segmentation_trainval.zip’
#
# supertux_segmentati 100%[===================>]  54.54M  46.1MB/s    in 1.2s
#
# 2021-06-20 00:49:35 (46.1 MB/s) - ‘supertux_segmentation_trainval.zip’ saved [57184517/57184517]

# %%
# !ls

# !cd cs342
# Out:
# cs342	     supertux_classification_trainval.zip
# dense_data   supertux_segmentation_trainval.zip
# sample_data  supertux_segmentation_trainval.zip.1

# %%
# !cd /content/cs342/homework2

# %%
cd /content/cs342/homework2/
# Out:
# /content/cs342/homework2

# %%
# !pwd
# Out:
# /content/cs342/homework2

# %%
# !python -m grader homework -v
# Out:
# Loading assignment
# Loading grader
#  * CNN model
#   - is a cnn                                           [ Function not implemented  ]
#  --------------------------------------------------    [   0 /  10 ]
#
#  * Log correctness
#   - Log training accuracies                            [ passed ]
#   - Log training loss                                  [ passed ]
#   - Log valid accuracies                               [ passed ]
#  --------------------------------------------------    [  30 /  30 ]
#
#  * Trained CNN model
#   - Accuracy                                           [ Crash "[Errno 2] No such file or directory: '/content/cs342/homework2/homework/cnn.th'" ]
#  --------------------------------------------------    [   0 /  60 ]
#
#
# total score                                               30 / 100

# %%
cd /content/cs342/homework2/
# Out:
# /content/cs342/homework2

# %%
# !git add homework/*.py
# !git config --global user.email "veenasravanti@gmail.com"
# !git config --global user.name "veenasravanti"
# !git commit -m "Renaming logging file"
# !git push origin master
# Out:
# Streaming output truncated to the last 5000 lines.
# 	data/valid/04008.jpg
# 	data/valid/04009.jpg
# 	data/valid/04010.jpg
# 	data/valid/04011.jpg
# 	data/valid/04012.jpg
# 	data/valid/04013.jpg
# 	data/valid/04014.jpg
# 	data/valid/04015.jpg
# 	data/valid/04016.jpg
# 	data/valid/04017.jpg
# 	data/valid/04018.jpg
# 	data/valid/04019.jpg
# 	data/valid/04020.jpg
# 	data/valid/04021.jpg
# 	data/valid/04022.jpg
# 	data/valid/04023.jpg
# 	data/valid/04024.jpg
# 	data/valid/04025.jpg
# 	data/valid/04026.jpg
# 	data/valid/04027.jpg
# 	data/valid/04028.jpg
# 	data/valid/04029.jpg
# 	data/valid/04030.jpg
# 	data/valid/04031.jpg
# 	data/valid/04032.jpg
# 	data/valid/04033.jpg
# 	data/valid/04034.jpg
# 	data/valid/04035.jpg
# 	data/valid/04036.jpg
# 	data/valid/04037.jpg
# 	data/valid/04038.jpg
# 	data/valid/04039.jpg
# 	data/valid/04040.jpg
# 	data/valid/04041.jpg
# 	data/valid/04042.jpg
# 	data/valid/04043.jpg
# 	data/valid/04044.jpg
# 	data/valid/04045.jpg
# 	data/valid/04046.jpg
# ...

# %%
# !python3 -m homework.train
# Out:
# tensor([[[[0.2275, 0.2078, 0.0941,  ..., 0.4902, 0.5020, 0.4980],
#           [0.2941, 0.1843, 0.3686,  ..., 0.5059, 0.4902, 0.4745],
#           [0.4039, 0.3176, 0.6588,  ..., 0.5098, 0.4824, 0.4902],
#           ...,
#           [0.4471, 0.4471, 0.4431,  ..., 0.4471, 0.4549, 0.4549],
#           [0.4471, 0.4392, 0.4471,  ..., 0.4196, 0.4275, 0.4431],
#           [0.4314, 0.4275, 0.4314,  ..., 0.4157, 0.4196, 0.4510]],
#
#          [[0.2314, 0.2118, 0.0980,  ..., 0.4392, 0.4706, 0.4745],
#           [0.2824, 0.1725, 0.3569,  ..., 0.4667, 0.4667, 0.4706],
#           [0.3686, 0.2824, 0.6235,  ..., 0.4902, 0.4784, 0.5020],
#           ...,
#           [0.4784, 0.4667, 0.4471,  ..., 0.4392, 0.4431, 0.4353],
#           [0.4863, 0.4706, 0.4510,  ..., 0.4392, 0.4392, 0.4549],
#           [0.4745, 0.4588, 0.4353,  ..., 0.4588, 0.4549, 0.4784]],
#
#          [[0.2078, 0.1882, 0.0745,  ..., 0.4784, 0.5137, 0.5137],
#           [0.2549, 0.1451, 0.3373,  ..., 0.5020, 0.5059, 0.5020],
# ...
